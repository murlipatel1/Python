# %% [markdown]
# # MURLI PATEL
# ## 21BCP107

# %% [markdown]
# ###Practice the examples provided in the ppt.

# %%
import matplotlib.pyplot as plt  
import numpy as np
xpoints = np.array([0, 6]) 
ypoints =np.array([0, 250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
ypoints=np.array([3,8,1,10])  
plt.plot(ypoints, marker = 'o')  
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
xpoints = np.array([1, 8]) 
ypoints =np.array([3, 10])
plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np  
#plot1:
x=np.array([0,1,2,3])
y =np.array([3, 10, 1, 8])
plt.subplot(1, 2,1) 
plt.plot(x,y)
#plot2:
x=np.array([0,1,2,3])
y =np.array([10, 20, 30, 40])
plt.subplot(1, 2,2) 
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt  
import numpy as np 
x =np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y =np.array([99,86,86,88,100,86,103,87,90,78,77,80,86])
plt.scatter(x,y)  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
x =np.random.normal(160, 10, 250) 
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt  
import numpy as np 
y =np.array([35, 25, 25, 10,5])
mylabels = ["Apples", "Bananas", "Cherries","Dates", "Kiwi"] 
#mycolors =["black", "hotpink", "b", "#4CAF50"]
plt.pie(y, labels =mylabels) 
plt.show()

# %% [markdown]
# ###Draw two different plots in the same graph (multiple plots),
# ###consisting of following:
# ####a)Pie Chart
# ####b)Line Graph

# %%
import matplotlib.pyplot as plt  
import numpy as np 
#plot1:
y =np.array([45, 20, 20, 10,5])
mylabels = ["Car", "Bike", "Plan","Jet", "Ship"] 
#mycolors =["black", "hotpink", "b", "#4CAF50"]
plt.pie(y, labels =mylabels) 
plt.show()

#plot2:
x=np.array([0,1,2,3])
y =np.array([10, 20, 30, 40])
plt.subplot(1, 2,2) 
plt.plot(x,y)
plt.show()
